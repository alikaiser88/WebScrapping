# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def scrap_upc_code(URL):
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html5lib')
    row = soup.find('div', attrs = {'class':'product__stat'}) 
    if row == None: 
        return ""
    row2 = row.find('span', attrs = {'class':'product__stat-desc'})
    #print(row2.text)  # UPC code
    if row2 == None: 
        return ""    
    return row2.text.strip('\n')



def scrap_url(URL, keyword):
    url_list=[]
    
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html5lib')
    #quotes=[]  # a list to store quotes
    table = soup.find('div', attrs = {'id':'product_listing'}) 
    if table == None: 
        #print("table Not found ")
        return None 
    
    nxt_page = soup.find('li', attrs = {'class':'rc-pagination-next'})
    #print(nxt_page)
    nxt_pagetag= nxt_page.find('a')
    if nxt_pagetag is not None:
        nxt_pagelink= nxt_pagetag.attrs["href"]
        #print(nxt_pagelink)
    
    
    else :
        nxt_pagelink= None
    
    
    ret_obj = {}
    ret_obj['Next_url']= nxt_pagelink

    for row in table.findAll('div',
                              attrs = {'class':'ag-item gtm-product'}):
        item = {}
        details_tag= row.find('div', attrs = {'id':'details'})
        #print(row.attrs["data-item-number"])  # SKU id
        item['sku'] = row.attrs["data-item-number"]
        a_tag= details_tag.find('a', attrs = {'class':'block'})
        #print(a_tag.text)  # Product description
        item['description'] = a_tag.text
        #print("https://www.webstaurantstore.com" + a_tag.attrs["href"])  # SKU id
        item['url'] =("https://www.webstaurantstore.com" + a_tag.attrs["href"])
        pricing_tag= row.find('div', attrs = {'class':'pricing'})
        a2_tag= pricing_tag.find('p')
        #print(a2_tag.text)  # price
        item['price'] = a2_tag.text
        item['UPC'] = scrap_upc_code(item['url'])
        item['keyword'] = keyword
        url_list.append(item)
    
    ret_obj['Product_list']= url_list
    return ret_obj





#base_url ="https://www.webstaurantstore.com/search/chair.html"
#product_list=[]


#for p in range(1, 10):
#    page_url = base_url+"?page=" + str(p)
#    print(page_url)
#    obj_list = scrap_url(page_url)
#    product_list.extend(obj_list)
#url = base_url

#while url is not None: 
#    obj_list = scrap_url(url, )

 #   if obj_list is not None : 
#
 #       product_list.extend(obj_list['Product_list'])

#        url= obj_list['Next_url']
#        print(url)
#
#        if url is not None :

#            url_array = base_url.split('/')
#            print(url_array)
#            new_url=url_array[0] +"//" + url_array[2]+ url
#            print (new_url)
 #           url = new_url

# %%
word_List= ['Kitchen utensils','Food preparation tools','Tongs','Disposables','Restaurant dinnerware','Tabletop',
              'Food storage containers','Spice storage containers','Kitchen spoons','Turners',
              'Whisks and cooking whips','Pizza servers','Ice cream scoop and dippers','Measuring cups and spoons',
              'Disposable food packaging supplies']

# %%
print (word_List)
# Out:
# ['Kitchen utensils', 'Food preparation tools', 'Tongs', 'Disposables', 'Restaurant dinnerware', 'Tabletop', 'Food storage containers', 'Spice storage containers', 'Kitchen spoons', 'Turners', 'Whisks and cooking whips', 'Pizza servers', 'Ice cream scoop and dippers', 'Measuring cups and spoons', 'Disposable food packaging supplies']

# %%
x = [word.replace(" ", "-").lower() for word in word_List ]
print(x)
# Out:
# ['kitchen-utensils', 'food-preparation-tools', 'tongs', 'disposables', 'restaurant-dinnerware', 'tabletop', 'food-storage-containers', 'spice-storage-containers', 'kitchen-spoons', 'turners', 'whisks-and-cooking-whips', 'pizza-servers', 'ice-cream-scoop-and-dippers', 'measuring-cups-and-spoons', 'disposable-food-packaging-supplies']

# %%
word_List = list(set(x))

# %%
word_List.sort()

# %%
print(word_List)
# Out:
# ['disposable-food-packaging-supplies', 'disposables', 'food-preparation-tools', 'food-storage-containers', 'ice-cream-scoop-and-dippers', 'kitchen-spoons', 'kitchen-utensils', 'measuring-cups-and-spoons', 'pizza-servers', 'restaurant-dinnerware', 'spice-storage-containers', 'tabletop', 'tongs', 'turners', 'whisks-and-cooking-whips']

# %%
product_list=[]
for word in word_List :
    base_url ="https://www.webstaurantstore.com/search/"+word +".html"
    print(base_url)
    #break
    
    url = base_url

    while url is not None: 
        obj_list = scrap_url(url, word)

        if obj_list is None:
            url = None
        else:             
            product_list.extend(obj_list['Product_list'])

            url= obj_list['Next_url']
            #print(url)

            if url is not None :

                url_array = base_url.split('/')
                #print(url_array)
                new_url=url_array[0] +"//" + url_array[2]+ url
                print (new_url)
                url = new_url
# Out:
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=2
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=3
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=4
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=5
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=6
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=7
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=8
# https://www.webstaurantstore.com/search/disposable-food-packaging-supplies.html?page=9
# https://www.webstaurantstore.com/search/disposables.html
# https://www.webstaurantstore.com/search/food-preparation-tools.html
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=2
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=3
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=4
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=5
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=6
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=7
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=8
# https://www.webstaurantstore.com/search/food-preparation-tools.html?page=9
# https://www.webstaurantstore.com/search/food-storage-containers.html
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=2
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=3
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=4
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=5
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=6
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=7
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=8
# https://www.webstaurantstore.com/search/food-storage-containers.html?page=9
# https://www.webstaurantstore.com/search/ice-cream-scoop-and-dippers.html
# https://www.webstaurantstore.com/search/ice-cream-scoop-and-dippers.html?page=2
# https://www.webstaurantstore.com/search/ice-cream-scoop-and-dippers.html?page=3
# https://www.webstaurantstore.com/search/kitchen-spoons.html
# https://www.webstaurantstore.com/search/kitchen-spoons.html?page=2
# https://www.webstaurantstore.com/search/kitchen-spoons.html?page=3
# https://www.webstaurantstore.com/search/kitchen-spoons.html?page=4
# https://www.webstaurantstore.com/search/kitchen-spoons.html?page=5
# https://www.webstaurantstore.com/search/kitchen-spoons.html?page=6
# https://www.webstaurantstore.com/search/kitchen-utensils.html
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=2
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=3
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=4
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=5
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=6
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=7
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=8
# https://www.webstaurantstore.com/search/kitchen-utensils.html?page=9
# https://www.webstaurantstore.com/search/measuring-cups-and-spoons.html
# https://www.webstaurantstore.com/search/measuring-cups-and-spoons.html?page=2
# https://www.webstaurantstore.com/search/measuring-cups-and-spoons.html?page=3
# https://www.webstaurantstore.com/search/measuring-cups-and-spoons.html?page=4
# https://www.webstaurantstore.com/search/pizza-servers.html
# https://www.webstaurantstore.com/search/pizza-servers.html?page=2
# https://www.webstaurantstore.com/search/pizza-servers.html?page=3
# https://www.webstaurantstore.com/search/pizza-servers.html?page=4
# https://www.webstaurantstore.com/search/pizza-servers.html?page=5
# https://www.webstaurantstore.com/search/pizza-servers.html?page=6
# https://www.webstaurantstore.com/search/pizza-servers.html?page=7
# https://www.webstaurantstore.com/search/pizza-servers.html?page=8
# https://www.webstaurantstore.com/search/pizza-servers.html?page=9
# https://www.webstaurantstore.com/search/restaurant-dinnerware.html
# https://www.webstaurantstore.com/search/spice-storage-containers.html
# https://www.webstaurantstore.com/search/spice-storage-containers.html?page=2
# https://www.webstaurantstore.com/search/spice-storage-containers.html?page=3
# https://www.webstaurantstore.com/search/spice-storage-containers.html?page=4
# https://www.webstaurantstore.com/search/tabletop.html
# https://www.webstaurantstore.com/search/tabletop.html?page=2
# https://www.webstaurantstore.com/search/tabletop.html?page=3
# https://www.webstaurantstore.com/search/tabletop.html?page=4
# https://www.webstaurantstore.com/search/tabletop.html?page=5
# https://www.webstaurantstore.com/search/tabletop.html?page=6
# https://www.webstaurantstore.com/search/tabletop.html?page=7
# https://www.webstaurantstore.com/search/tabletop.html?page=8
# https://www.webstaurantstore.com/search/tabletop.html?page=9
# https://www.webstaurantstore.com/search/tongs.html
# https://www.webstaurantstore.com/search/tongs.html?page=2
# https://www.webstaurantstore.com/search/tongs.html?page=3
# https://www.webstaurantstore.com/search/tongs.html?page=4
# https://www.webstaurantstore.com/search/tongs.html?page=5
# https://www.webstaurantstore.com/search/tongs.html?page=6
# https://www.webstaurantstore.com/search/tongs.html?page=7
# https://www.webstaurantstore.com/search/tongs.html?page=8
# https://www.webstaurantstore.com/search/tongs.html?page=9
# https://www.webstaurantstore.com/search/turners.html
# https://www.webstaurantstore.com/search/turners.html?page=2
# https://www.webstaurantstore.com/search/turners.html?page=3
# https://www.webstaurantstore.com/search/turners.html?page=4
# https://www.webstaurantstore.com/search/turners.html?page=5
# https://www.webstaurantstore.com/search/turners.html?page=6
# https://www.webstaurantstore.com/search/turners.html?page=7
# https://www.webstaurantstore.com/search/whisks-and-cooking-whips.html
# https://www.webstaurantstore.com/search/whisks-and-cooking-whips.html?page=2

# %%
df= pd.DataFrame(product_list)

# %%
df
# Out:
#                sku                                        description  \
# 0        433nhtbio  Green Herc 1/6 Size Biodegradable Plastic T-Sh...
# 1           150403  Choice 12" x 12" Newspaper Print Deli Sandwich...
# 2         12212105  Choice 12" x 10 3/4" Food Service Interfolded ...
# 3     245wedgepzza  Choice White Clay Coated Clamshell Pizza Slice...
# 4     433300100nat  Choice 6" x 1" x 8" Kraft Customizable Sandwic...
# ...            ...                                                ...
# 5184     980111060  Matfer Bourgeat 40" Giant Stainless Steel Pian...
# 5185     980111026  Matfer Bourgeat 18" Stainless Steel Piano Whip...
# 5186     980111035  Matfer Bourgeat 15 3/4" Stainless Steel Rigid ...
# 5187     980111036  Matfer Bourgeat 17 3/4" Stainless Steel Rigid ...
# 5188  407mtchastnd        Tenzo Porcelain Matcha Whisk Stand / Holder
#
#                                                     url             price  \
# 0     https://www.webstaurantstore.com/green-herc-1-...  From $25.11/Case
# 1     https://www.webstaurantstore.com/choice-12-x-1...       $32.99/Case
# 2     https://www.webstaurantstore.com/choice-12-x-1...   From $16.99/Box
# 3     https://www.webstaurantstore.com/choice-white-...  From $70.92/Case
# 4     https://www.webstaurantstore.com/choice-6-x-1-...       $41.99/Case
# ...                                                 ...               ...
# 5184  https://www.webstaurantstore.com/matfer-bourge...      $304.49/Each
# 5185  https://www.webstaurantstore.com/matfer-bourge...  From $36.40/Each
# 5186  https://www.webstaurantstore.com/matfer-bourge...  From $42.90/Each
# 5187  https://www.webstaurantstore.com/matfer-bourge...  From $44.85/Each
# 5188  https://www.webstaurantstore.com/tenzo-porcela...        $9.99/Each
#
#                                  keyword
# 0     disposable-food-packaging-supplies
# 1     disposable-food-packaging-supplies
# 2     disposable-food-packaging-supplies
# 3     disposable-food-packaging-supplies
# 4     disposable-food-packaging-supplies
# ...                                  ...
# 5184            whisks-and-cooking-whips
# 5185            whisks-and-cooking-whips
# 5186            whisks-and-cooking-whips
# 5187            whisks-and-cooking-whips
# 5188            whisks-and-cooking-whips
#
# [5189 rows x 5 columns]

# %%
df.to_csv("export2.csv")

# %%
print( "Done")
# Out:
# Done
